# %% [markdown]
# <a href="https://colab.research.google.com/github/davigomes05/aula-01/blob/main/aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
materias = ['Matemática','História','Biologia']
notas = (8.5 , 7.0 , 9.2)
aluno = {'nome:': 'Carlos', 'idade': 21, 'curso':'engenharia'}

print("Matérias:", materias)
print("Notas:", notas)
print("Informações do aluno:", aluno)
# Out:
# Matérias: ['Matemática', 'História', 'Biologia']
# Notas: (8.5, 7.0, 9.2)
# Informações do aluno: {'nome:': 'Carlos', 'idade': 21, 'curso': 'engenharia'}

# %%
acessorios = ['Rodas','Volante','Cinto']
especificacoes = (600 cavalos, 60 litros)
carro = {'Marca:': 'Ferrari', 'Modelo:': 'Esportivo', 'Ano:': 2020}

print("Acessórios:", acessorios)
print("Especificações:", especificacoes)
print("Carro:", carro)
# Out:
# Acessórios: ['Rodas', 'Volante', 'Cinto']
# Especificações: ('600 cavalos', '60 litros')
# Carro: {'Marca:': 'Ferrari', 'Modelo:': 'Esportivo', 'Ano:': 2020}
