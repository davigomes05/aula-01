# %%
nome = "João Silva"
idade = 25
profissao = "Desenvolvedor"
print("Seu nome é:", nome)
print("Sua idade é:", idade)
print("Sua profissão é:", profissao)
# Out:
# Seu nome é: João Silva
# Sua idade é: 25
# Sua profissão é: Desenvolvedor

# %%
produto = "Notebook"
marca = "Dell"
preco = 4500
print("Produto :", produto)
print("Marca :", marca)
print(f"Preço R$ {preco:.2f}")
# Out:
# Produto : Notebook
# Marca : Dell
# Preço R$ 4500.00

# %%
num1 = 12
num2 = 6
soma = 18
subtracao = 6
multiplicacao = 72
divisao = 2.0
print(num1 + num2)
# Out:
# 18

# %%
num1 = 7
num = 2
soma = num1 + num2
sub = num1 - num2
mult = num1 * num2
div = num1 / num2
potenciacao = num1 ** num2
print()
# Out:
# Soma: 13
#  Subtração: 1
#  Multiplicação: 42
#  Divisão: 1.1666666666666667
